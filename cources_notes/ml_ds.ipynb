# %%
import pandas as pd
import numpy as np

# %%
doka = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')

# %%
doka.head(20)
# Out:
#     Unnamed: 0 attack_type  id  legs   localized_name  \
# 0            0       Melee   1     2        Anti-Mage
# 1            1       Melee   2     2              Axe
# 2            2      Ranged   3     4             Bane
# 3            3       Melee   4     2      Bloodseeker
# 4            4      Ranged   5     2   Crystal Maiden
# 5            5      Ranged   6     2      Drow Ranger
# 6            6       Melee   7     2      Earthshaker
# 7            7       Melee   8     2       Juggernaut
# 8            8      Ranged   9     2           Mirana
# 9            9      Ranged  10     0        Morphling
# 10          10      Ranged  11     0     Shadow Fiend
# 11          11       Melee  12     2   Phantom Lancer
# 12          12      Ranged  13     2             Puck
# 13          13       Melee  14     2            Pudge
# 14          14      Ranged  15     0            Razor
# 15          15       Melee  16     6        Sand King
# ...

# %%
doka.groupby('legs').nunique()
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11            2  11              11    11             3     11
# 2             95            2  95              95    95             3     81
# 4              7            2   7               7     7             3      7
# 6              3            2   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
doka.groupby(['attack_type', 'primary_attr']).agg({'id':'count'}).sort_values('id', ascending=False)
# Out:
#                           id
# attack_type primary_attr
# Ranged      int           40
# Melee       str           35
#             agi           19
# Ranged      agi           18
#             str            3
# Melee       int            2

# %%
doka['cnt'] = doka.roles.str.count(',') + 1

# %%
sns.histplot(data=doka, x='cnt', discrete=True);

# %%
poopa_loopa = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')

# %%
poopa_loopa.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
poopa_loopa \
    .groupby(['Type', 'Executor']) \
    .agg({'Salary':'mean'}) \
    .sort_values(['Type', 'Salary'], ascending=[True,False]) \
    .groupby('Type') \
    .head(1)
# Out:
#                    Salary
# Type Executor
# A    Pupa      160.833333
# B    Loopa     145.166667
# C    Loopa     154.333333
# D    Pupa      146.500000
# E    Loopa     164.000000
# F    Loopa     238.000000

# %%
concentrations = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')

# %%
mean_concentrations = concentrations.groupby('genus').mean()
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
round(concentrations.query('genus == "Fucus"').alanin.describe(), 2)
# Out:
# count    3.00
# mean     3.57
# std      3.15
# min      0.35
# 25%      2.03
# 50%      3.71
# 75%      5.18
# max      6.64
# Name: alanin, dtype: float64

# %%
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
concentrations.groupby('group').describe()['citrate']
# Out:
#        count      mean       std       min       25%       50%       75%  \
# group
# brown    6.0  4.098597  2.338577  1.071920  2.163641  5.128895  5.529506
# green    3.0  5.288311  1.987489  3.082826  4.462173  5.841520  6.391054
# red      1.0  5.573905       NaN  5.573905  5.573905  5.573905  5.573905
#
#             max
# group
# brown  6.423606
# green  6.940588
# red    5.573905

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.plot(df.index, df.income)
df.income.plot()
sns.lineplot(data=df)
sns.lineplot(x=df.index, y=df.income)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a497f2b9d99d> in <module>
# ----> 1 plt.plot(df.index, df.income)
#       2 df.income.plot()
#       3 sns.lineplot(data=df)
#       4 sns.lineplot(x=df.index, y=df.income)
#
# NameError: name 'df' is not defined

# %%
data=pd.read_csv('C:/Users/User/jupyter_pr/data_frames/dataset_209770_6.txt', sep=' ')

# %%
sns.lmplot(x='x', y='y', data=data, fit_reg=False)

# %%
heat = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv', index_col=0)

# %%
g = sns.heatmap(data=heat, cmap="viridis")
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
iris = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv')

# %%
iris
# Out:
#      sepal length  sepal width  petal length  petal width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = iris.drop('Unnamed: 0', axis='columns')

# %%
iris['species'].replace([0,1,2],['setosa', 'versicolor', 'virginica'],inplace=True)

# %%
sns.kdeplot(data=iris);

# %%
sns.violinplot(y='petal length', data=iris, color='Purple')
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
sns.pairplot(iris, hue='species')

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')

# %%
my_stat.head()
# Out:
#    V1    V2 V3   V4
# 0   2  13.0  B  1.0
# 1  -1   7.0  B  1.0
# 2   0  11.0  A  0.0
# 3   2  11.0  A  2.0
# 4   0  10.0  B -1.0

# %%
subset_2 = my_stat.drop([0, 4], axis='index').iloc[:, [1, 3]]

# %%
subset_1 = my_stat[(my_stat.V1 > 0) & (my_stat.V3 == 'A')]

# %%
subset_2 = my_stat[(my_stat.V2 != 10) | (my_stat.V4 >= 1)]

# %%
my_stat.assign(V7=lambda x: x.V5 + x.V6)
# Out:
#      V1    V2 V3   V4   V5        V6        V7
# 0     2  13.0  B  1.0  3.0  2.564949  5.564949
# 1    -1   7.0  B  1.0  0.0  1.945910  1.945910
# 2     0  11.0  A  0.0  0.0  2.397895  2.397895
# 3     2  11.0  A  2.0  4.0  2.397895  6.397895
# 4     0  10.0  B -1.0 -1.0  2.302585  1.302585
# ..   ..   ... ..  ...  ...       ...       ...
# 495   1   8.0  A -1.0  0.0  2.079442  2.079442
# 496   3   8.0  A  1.0  4.0  2.079442  6.079442
# 497  -1  11.0  B  2.0  1.0  2.397895  3.397895
# 498   1  11.0  A  2.0  3.0  2.397895  5.397895
# 499   0   8.0  B  1.0  1.0  2.079442  3.079442
#
# [500 rows x 7 columns]

# %%
my_stat['V6'] = np.log(my_stat.V2)

# %%
my_stat = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')

# %%
my_stat = my_stat.rename(columns={'V1':'session_value', 'V2':'group', 'V3':'time', 'V4':'n_users'})

# %%
my_stat.head()
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A        5
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9

# %%
my_stat.session_value = my_stat.session_value.fillna(0)

# %%
my_stat.query('n_users < 0') = my_stat.n_users[my_stat.n_users > 0].median()
# Out:
#   File "<ipython-input-143-157cb4ee46b1>", line 1
#     my_stat.query('n_users < 0') = my_stat.n_users[my_stat.n_users > 0].median()
#     ^
# SyntaxError: cannot assign to function call

# %%
my_stat.loc[my_stat['n_users'] < 0, 'n_users'] = my_stat.n_users[my_stat.n_users >= 0].median()

# %%
df = pd.DataFrame({'type':['A', 'A', 'B', 'B'], 'value':[10, 14, 12, 23]})

# %%
df
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23
