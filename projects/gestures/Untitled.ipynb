# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.decomposition import PCA

# %%
a1_raw = pd.read_csv("a1_raw.csv")
a1_va3 = pd.read_csv('a1_va3.csv')

# %%
a1_raw.shape
# Out:
# (1747, 20)

# %%
a1_va3.shape
# Out:
# (1743, 33)

# %%
a1 = pd.concat([a1_raw, a1_va3], axis=1, join='inner')

# %%
a1.head()
# Out:
#         lhx       lhy       lhz       rhx       rhy       rhz        hx  \
# 0  5.347435  4.363681  1.501913  5.258967  4.319263  1.488703  5.037871
# 1  4.869622  4.254210  1.556133  5.240113  4.346338  1.554309  5.037610
# 2  5.357447  4.364039  1.500969  5.238928  4.347924  1.554150  5.037514
# 3  4.942886  4.281878  1.546513  5.111436  4.229660  1.527091  5.037526
# 4  5.003160  4.278530  1.542866  4.985812  4.182155  1.520330  5.037557
#
#          hy        hz        sx  ...            24        25        26  \
# 0  1.618295  1.778350  5.062803  ...  1.880800e-04  0.005133  0.010400
# 1  1.618370  1.778573  5.061430  ... -7.500000e-07  0.005093  0.005756
# 2  1.618298  1.778774  5.059245  ... -3.920000e-05  0.002406  0.003279
# 3  1.618612  1.778855  5.056475  ... -3.184000e-05  0.001416  0.001334
# 4  1.619226  1.778925  5.052367  ... -2.015000e-05  0.000158  0.001709
#
#          27        28        29        30        31        32 Phase
# ...

# %%
a1.describe()
# Out:
#                lhx          lhy          lhz          rhx          rhy  \
# count  1743.000000  1743.000000  1743.000000  1743.000000  1743.000000
# mean      4.732483     4.110796     1.491870     5.402171     3.859569
# std       0.707155     0.783151     0.064088     0.808295     0.871245
# min       1.712471     1.660291     1.183290     3.653736     1.296046
# 25%       4.527199     3.696576     1.467732     4.848486     3.272972
# 50%       4.869606     4.267268     1.487925     5.199630     4.121761
# 75%       5.154901     4.737562     1.523728     5.821485     4.376167
# max       6.212834     5.414431     1.673418     8.546903     5.453834
#
#                rhz           hx           hy           hz           sx  ...  \
# count  1743.000000  1743.000000  1743.000000  1743.000000  1743.000000  ...
# mean      1.483825     5.084099     1.660450     1.753658     5.099319  ...
# std       0.070517     0.182156     0.058373     0.024086     0.126311  ...
# ...

# %%
a1_data = a1.drop(['phase', 'Phase'], axis=1)

# %%
pca = PCA(n_components=a1_data.shape[1])
a1_pca = pca.fit_transform(a1_data)

# %%
a1['phase'] = a1['phase'].map({'Rest' : 0, 'Preparation' : 1, 'Stroke' : 2, 'Hold' : 3, 'Retraction' : 4})

# %%
a1.corr()['phase']
# Out:
# lhx         -0.373128
# lhy         -0.322445
# lhz          0.013127
# rhx          0.390450
# rhy         -0.487342
# rhz          0.012195
# hx          -0.203442
# hy          -0.021285
# hz          -0.038785
# sx          -0.186613
# sy          -0.068694
# sz          -0.024778
# lwx         -0.359620
# lwy         -0.337256
# lwz         -0.147641
# rwx          0.375836
# rwy         -0.481112
# rwz         -0.110084
# timestamp   -0.085984
# phase        1.000000
# 1           -0.034491
# 2           -0.065267
# 3           -0.007141
# 4            0.064040
# 5           -0.103206
# 6            0.016718
# 7           -0.039516
# 8           -0.073305
# 9           -0.022456
# 10           0.056122
# 11          -0.103364
# 12           0.003308
# 13           0.006896
# 14           0.006168
# 15          -0.010000
# 16           0.003084
# 17          -0.009789
# 18          -0.009289
# 19           0.002008
# 20           0.005283
# 21          -0.014486
# ...
